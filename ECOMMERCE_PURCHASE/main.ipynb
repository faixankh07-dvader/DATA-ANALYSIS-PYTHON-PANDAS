# %%
import pandas as pd

# %%
data = pd.read_csv('Ecommerce Purchases')
data
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# 1 dispaly top and last 10 rows of the dataset

# %%
data.head(10)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %% [markdown]
# 2 DISPLAY LAST 10 ROWS OF DATASET

# %%
data.tail(10)
# Out:
#                                                 Address    Lot AM or PM  \
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9990  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4;...
# 9991  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# ...

# %% [markdown]
# 3 Check data type of each column

# %%
data.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %% [markdown]
# 4 check null values in dataset, number of columns and rows

# %%
missing_values = data.isnull().sum()
num_columns = len(data.columns)
num_rows = len(data)

missing_values, num_columns, num_rows
# Out:
# (Address             0
#  Lot                 0
#  AM or PM            0
#  Browser Info        0
#  Company             0
#  Credit Card         0
#  CC Exp Date         0
#  CC Security Code    0
#  CC Provider         0
#  Email               0
#  Job                 0
#  IP Address          0
#  Language            0
#  Purchase Price      0
#  dtype: int64,
#  14,
#  10000)

# %% [markdown]
# 5 Highest & Lowest Purchase Price / Average Purchase Price

# %%
c = data.columns
highest = data['Purchase Price'].max()
lowest = data['Purchase Price'].min()
average = data['Purchase Price'].mean()
purchase_stats = data["Purchase Price"].describe()

print(c)
print("Highest Purchase Price:", highest)
print("Lowest Purchase Price:", lowest)
print("Average Purchase Price:", average)
print("Purchase Price Stats:\n", purchase_stats)
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')
# Highest Purchase Price: 99.99
# Lowest Purchase Price: 0.0
# Average Purchase Price: 50.347302
# Purchase Price Stats:
#  count    10000.000000
# mean        50.347302
# std         29.015836
# min          0.000000
# 25%         25.150000
# 50%         50.505000
# 75%         75.770000
# max         99.990000
# Name: Purchase Price, dtype: float64

# %% [markdown]
# 6 How many people have French 'fr' as their Language. Display users who have english as their language.

# %%
french_users = len(data[data['Language']=='fr'])
print(french_users)

data[data['Language']=='en']
# Out:
# 1097
#                                                 Address    Lot AM or PM  \
# 11               349 Laurie Parks\nThomasview, ID 08970  30 kK       PM
# 12      733 Heather Rest Apt. 670\nBoltonport, UT 78662  69 DO       AM
# 22     625 Laura Summit Suite 112\nShortmouth, AK 97156  45 oa       PM
# 26          5334 Sheppard Fort\nNorth Kirsten, ND 71170  40 ND       AM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# ...                                                 ...    ...      ...
# 9961        714 Joshua Ridges\nCarpenterville, NJ 37418  84 rK       PM
# 9963  3865 Davis Meadow Suite 915\nPort Stacieview, ...  11 fo       AM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9973     92126 Daniel Streets\nNorth Patricia, IA 10477  04 QN       PM
# 9979  00490 Joseph Haven Apt. 149\nWest Keithfurt, S...  69 XK       PM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# 7 Job Analysis

# %%
lawyers_users = data[data["Job"].str.contains("lawyer", case=False)]
lawyers_num = len(data[data["Job"].str.contains("lawyer", case=False)])

analyst = len(data[data["Job"].str.contains("Analyst", case=False)])
print(analyst)

print(lawyers_num)

job_count = data["Job"].value_counts()

print(job_count)
lawyers_users
#visualization of jobs ( comparing analyst , engineer and manager)

job_keywords = ["Analyst", "Engineer", "Manager"]

job_counts = {}
for job in job_keywords:
    count = data["Job"].str.contains(job, case=False, na=False).sum()
    job_counts[job] = count

job_df = pd.DataFrame(
    list(job_counts.items()),
         columns=["Job Type", "Count"]
)
job_df.plot(
    x="Job Type",
    y="Count",
    kind="bar",
    legend=False,
    figsize=(8,5)
)
# Out:
# 61
# 30
# Job
# Interior and spatial designer        31
# Lawyer                               30
# Social researcher                    28
# Research officer, political party    27
# Designer, jewellery                  27
#                                      ..
# Stage manager                         7
# Actuary                               6
# Editor, film/video                    6
# Information systems manager           5
# Investment analyst                    5
# Name: count, Length: 623, dtype: int64
# <Axes: xlabel='Job Type'>

# %% [markdown]
# 8 Time Analysis

# %%
#AM vs PM Purchases

data["AM or PM"].value_counts()

import matplotlib.pyplot as plt

data["AM or PM"].value_counts().plot(kind="bar")
plt.show()

# %% [markdown]
# 9 Customers having mastercard as creditcard and purchase above 50

# %%
data[(data['CC Provider']=="Mastercard") & (data['Purchase Price']>50)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 90          431 Bowen Lights\nFergusonborough, MH 01362  31 tG       AM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  11 vG       AM
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  95 Kw       AM
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  65 Fg       PM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# 10 Most Expensive purchase

# %%
data.nlargest(5, 'Purchase Price')
# Out:
#                                                 Address    Lot AM or PM  \
# 2092          63773 Shelton Greens\nAshleyton, MA 00493  56 lu       AM
# 7807              PSC 6177, Box 1004\nAPO AA 57143-1269  64 Nf       AM
# 9856  058 Miranda Locks Suite 792\nPort Davidstad, P...  73 IW       PM
# 7604            672 James Oval\nNew Davidview, KS 91202  07 dT       PM
# 3844  27148 Kathy Cliff Apt. 400\nEast Jillton, TX 5...  37 ou       PM
#
#                                            Browser Info  \
# 2092  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 7807  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_4)...
# 9856  Mozilla/5.0 (Windows NT 5.0) AppleWebKit/5360 ...
# 7604  Mozilla/5.0 (Windows 98; Win 9x 4.90; it-IT; r...
# 3844  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
#
#                         Company       Credit Card CC Exp Date  \
# 2092                Pitts Group     4292741269160       06/18
# 7807  Porter, Johnson and Pratt    30109394842259       11/25
# ...

# %% [markdown]
# 11 Top Companies by Frequency

# %%
company = data["Company"].value_counts().head(5)

print(company)

data[data["Company"] =="Smith Group"]
# Out:
# Company
# Smith Group     15
# Brown Ltd       15
# Smith PLC       13
# Smith LLC       13
# Williams LLC    12
# Name: count, dtype: int64
# 15
#                                                 Address    Lot AM or PM  \
# 227         0448 Steve Hills\nWest Calebmouth, IN 67744  45 Uj       AM
# 427   2606 Jack Tunnel Suite 545\nSouth Kayla, KY 76852  01 VE       PM
# 1128  50266 Ricardo Light Apt. 378\nNew Kimberly, VT...  18 UI       PM
# 3060  9308 Joyce Curve\nNew Michaelmouth, WA 23313-8212  33 dz       PM
# 4490  142 Dixon Terrace Apt. 446\nJaredmouth, IL 603...  41 yZ       AM
# 4501                   PSC 7050, Box 8974\nAPO AE 10901  90 uq       AM
# 5088        8111 Lisa Ridge\nGlovermouth, MP 16160-2625  51 jq       AM
# 5244                   Unit 1912 Box 0903\nDPO AA 44397  57 mI       PM
# 5554            1839 Michael Hills\nAyersfurt, WV 43606  64 yE       PM
# 6224       05523 Shaw Green\nNorth Carla, DC 89832-3994  98 HX       AM
# ...

# %% [markdown]
# 12 Visualization of Purchase Price Distribution

# %%
import matplotlib.pyplot as plt

data["Purchase Price"].hist(bins=30)

plt.xlabel("Purchase Price")
plt.ylabel("Frequency")
plt.title("Purchase Price Distribution")

plt.show()

# %% [markdown]
# 13 Customer Segmentation

# %%
#Number of Purchases per Company
purchase_count = (
    data.groupby("Company")["Purchase Price"]
        .count()
        .sort_values(ascending=False)
)

print(purchase_count.head(10))

#Which language groups spend the most?Which spend the least?
data.groupby("Language")["Purchase Price"].mean().sort_values(ascending=False)
# Out:
# Company
# Brown Ltd         15
# Smith Group       15
# Smith PLC         13
# Smith LLC         13
# Williams LLC      12
# Davis and Sons    11
# Smith and Sons    11
# Brown Group       10
# Johnson LLC       10
# Johnson Ltd       10
# Name: Purchase Price, dtype: int64
# Language
# el    51.555356
# pt    51.215546
# en    51.103015
# de    50.254485
# zh    50.180198
# it    50.001004
# ru    49.927134
# fr    49.476718
# es    49.366977
# Name: Purchase Price, dtype: float64

# %% [markdown]
# 14 Revenue Analysis

# %%
company_revenue = data.groupby("Company")["Purchase Price"].sum()
print(company_revenue.sort_values(ascending=False))

#top ten revenue generating companies
print("\n----TOP 10 REVENUE GENERATING COMPANIES----")
top_companies = (
    data.groupby("Company")["Purchase Price"]
        .sum()
        .sort_values(ascending=False)
        .head(10)
)

print(top_companies)

print("\n----LEAST 10 REVENUE GENERATING COMPANIES----")
bottom_companies = (
    data.groupby("Company")["Purchase Price"]
        .sum()
        .sort_values(ascending=False)
        .tail(10)
)
print(bottom_companies)
# Out:
# Company
# Brown Ltd                796.38
# Williams LLC             723.63
# Smith LLC                637.92
# Smith PLC                601.37
# Johnson Ltd              600.61
#                           ...
# Washington-Johnson         0.03
# Armstrong PLC              0.02
# Sanchez-Stephenson         0.01
# Lyons, Diaz and Clark      0.00
# Flynn and Sons             0.00
# Name: Purchase Price, Length: 8653, dtype: float64
#
# ----TOP 10 REVENUE GENERATING COMPANIES----
# Company
# Brown Ltd         796.38
# Williams LLC      723.63
# Smith LLC         637.92
# Smith PLC         601.37
# Johnson Ltd       600.61
# Smith Group       592.54
# Johnson PLC       567.33
# Davis and Sons    560.09
# Brown Group       522.72
# Brown Inc         520.41
# Name: Purchase Price, dtype: float64
#
# ----LEAST 10 REVENUE GENERATING COMPANIES----
# Company
# Rice-Davis                0.10
# Hines, Sanchez and Cox    0.08
# Mills-Harper              0.07
# Martinez-Scott            0.06
# ...
